# %% [markdown]
# # Finding Hierarchical Ingredient Code List codes
#
# Most medications in eICU have a HICL code which we can use to find them in the database.

# %% [markdown]
# ## 0. Setup

# %%
# Must install pandas-gbq. Link: https://pandas-gbq.readthedocs.io/en/latest/install.html#pip
import math
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

project_id='lcp-internal'

# Helper function to read data from BigQuery into pandas dataframes.
def run_query(query):
    return pd.io.gbq.read_gbq(query,
                              project_id=project_id, verbose=False,
                              dialect='standard')

# %% [markdown]
# # 1. Find data which has that drug name
#
# This is a crude search that aims to (1) find a few HICLs and (2) find synonyms to the drug name (e.g. brand names).

# %%
# cohort with exclusions applied
compound = 'lasix'
query = f"""
select
    drughiclseqno, drugname, count(*) as n
from `physionet-data.eicu_crd.medication` med
where lower(drugname) like '%{compound}%'
group by drugname, drughiclseqno
order by n desc
"""
med = run_query(query)

print(med.shape)
display(med)
# Out:
# (17, 3)
#    drughiclseqno                                     drugname      n
# 0           3660                                        LASIX  17801
# 1           3660                                        Lasix   9301
# 2           3660                 furosemide (LASIX) inj 40 mg   3485
# 3           3660           furosemide (LASIX) injection 40 mg   1679
# 4           3660                 furosemide (LASIX) inj 20 mg   1530
# 5           3660              furosemide (LASIX) tablet 40 mg   1212
# 6           3660                 furosemide (LASIX) tab 40 mg   1078
# 7           3660  furosemide (LASIX) 10 mg/mL injection 40 mg   1033
# 8           3660           furosemide (LASIX) injection 20 mg   1005
# 9           None                                        LASIX    521
# 10          None                                        Lasix     92
# 11          None                 furosemide (LASIX) inj 40 mg     26
# 12          None                 furosemide (LASIX) tab 40 mg      7
# 13          None                 furosemide (LASIX) inj 20 mg      5
# 14          None           furosemide (LASIX) injection 20 mg      4
# 15          None           furosemide (LASIX) injection 40 mg      3
# 16          None              furosemide (LASIX) tablet 40 mg      1

# %% [markdown]
# From the above, we can be fairly confident that 3660 is our HICL code. Of course, it's also worth noting that we need to retain a search for the drug name as not all rows have a HICL code.
#
# We now proceed to expand our search to (1) the new HICL and (2) any other names which may be associated with lasix (e.g. from the above, furosemide is a clear candidate).

# %%
# cohort with exclusions applied
hicl = 3660
query = f"""
select
    drughiclseqno, drugname, count(*) as n
from `physionet-data.eicu_crd.medication` med
where drughiclseqno = {hicl}
group by drugname, drughiclseqno
order by n desc
"""
med = run_query(query)
print(med.shape)
display(med)
# Out:
# (35, 3)
#     drughiclseqno                                     drugname      n
# 0            3660                                   FUROSEMIDE  29030
# 1            3660                                         None  19522
# 2            3660                                        LASIX  17801
# 3            3660                                        Lasix   9301
# 4            3660         4 ML  -  FUROSEMIDE 10 MG/ML IJ SOLN   7797
# 5            3660                                   furosemide   6862
# 6            3660            FUROSEMIDE 10 MG/1 ML 2ML SDV INJ   6862
# 7            3660            FUROSEMIDE 10 MG/1 ML 4ML SDV INJ   6609
# 8            3660                     FUROSEMIDE 40 MG PO TABS   6202
# 9            3660      4 ML VIAL : FUROSEMIDE 10 MG/ML IJ SOLN   4811
# 10           3660       2 ML VIAL: FUROSEMIDE 10 MG/ML IJ SOLN   3848
# 11           3660                     FUROSEMIDE 20 MG PO TABS   3677
# 12           3660                 furosemide (LASIX) inj 40 mg   3485
# 13           3660           4 ML : FUROSEMIDE 10 MG/ML IJ SOLN   3360
# 14           3660                  FUROSEMIDE 10 MG/ML IJ SOLN   3007
# 15           3660       4 ML VIAL: FUROSEMIDE 10 MG/ML IJ SOLN   2974
# 16           3660                               FUROSEMIDE INJ   2920
# 17           3660                FUROSEMIDE 20 MG/2ML INJ SOLN   2557
# 18           3660                 FUROSEMIDE 10 MG/ML INJ SOLN   2371
# 19           3660     4 ML VIAL : FUROSEMIDE 10 MG/ML INJ SOLN   2124
# 20           3660      4 ml vial : furosemide 10 mg/ml ij soln   1965
# 21           3660         2 ML  -  FUROSEMIDE 10 MG/ML IJ SOLN   1770
# 22           3660                         FUROSEMIDE 40 MG TAB   1726
# 23           3660           furosemide (LASIX) injection 40 mg   1679
# 24           3660                 furosemide (LASIX) inj 20 mg   1530
# 25           3660                         FUROSEMIDE 20 MG TAB   1422
# 26           3660                       Furosemide 10mg/ml SSO   1385
# 27           3660              furosemide (LASIX) tablet 40 mg   1212
# 28           3660           2 ML : FUROSEMIDE 10 MG/ML IJ SOLN   1188
# 29           3660                FUROSEMIDE 40 MG/4ML INJ SOLN   1168
# 30           3660                 furosemide (LASIX) tab 40 mg   1078
# 31           3660                                   Furosemide   1033
# 32           3660  furosemide (LASIX) 10 mg/mL injection 40 mg   1033
# 33           3660           furosemide (LASIX) injection 20 mg   1005
# 34           3660                     FUROSEMIDE 80 MG PO TABS    995

# %% [markdown]
# Looks like the only additional term we should search for is furosemide.

# %%
compound1 = 'lasix'
compound2 = 'furosemide'
query = f"""
select
    drughiclseqno, drugname, count(*) as n
from `physionet-data.eicu_crd.medication` med
where lower(drugname) like '%{compound1}%'
OR lower(drugname) like '%{compound2}%'
group by drugname, drughiclseqno
order by n desc
"""
med = run_query(query)
print(med.shape)
display(med)
# Out:
# (61, 3)
#    drughiclseqno                                     drugname      n
# 0           3660                                   FUROSEMIDE  29030
# 1           3660                                        LASIX  17801
# 2           3660                                        Lasix   9301
# 3           3660         4 ML  -  FUROSEMIDE 10 MG/ML IJ SOLN   7797
# 4           3660            FUROSEMIDE 10 MG/1 ML 2ML SDV INJ   6862
# 5           3660                                   furosemide   6862
# 6           3660            FUROSEMIDE 10 MG/1 ML 4ML SDV INJ   6609
# 7           3660                     FUROSEMIDE 40 MG PO TABS   6202
# 8           3660      4 ML VIAL : FUROSEMIDE 10 MG/ML IJ SOLN   4811
# 9           3660       2 ML VIAL: FUROSEMIDE 10 MG/ML IJ SOLN   3848
# 10          3660                     FUROSEMIDE 20 MG PO TABS   3677
# 11          3660                 furosemide (LASIX) inj 40 mg   3485
# 12          3660           4 ML : FUROSEMIDE 10 MG/ML IJ SOLN   3360
# 13          3660                  FUROSEMIDE 10 MG/ML IJ SOLN   3007
# 14          3660       4 ML VIAL: FUROSEMIDE 10 MG/ML IJ SOLN   2974
# 15          3660                               FUROSEMIDE INJ   2920
# 16          3660                FUROSEMIDE 20 MG/2ML INJ SOLN   2557
# 17          3660                 FUROSEMIDE 10 MG/ML INJ SOLN   2371
# 18          3660     4 ML VIAL : FUROSEMIDE 10 MG/ML INJ SOLN   2124
# 19          3660      4 ml vial : furosemide 10 mg/ml ij soln   1965
# 20          3660         2 ML  -  FUROSEMIDE 10 MG/ML IJ SOLN   1770
# 21          3660                         FUROSEMIDE 40 MG TAB   1726
# 22          3660           furosemide (LASIX) injection 40 mg   1679
# 23          3660                 furosemide (LASIX) inj 20 mg   1530
# 24          3660                         FUROSEMIDE 20 MG TAB   1422
# 25          3660                       Furosemide 10mg/ml SSO   1385
# 26          3660              furosemide (LASIX) tablet 40 mg   1212
# 27          None         4 ML  -  FUROSEMIDE 10 MG/ML IJ SOLN   1209
# 28          3660           2 ML : FUROSEMIDE 10 MG/ML IJ SOLN   1188
# 29          3660                FUROSEMIDE 40 MG/4ML INJ SOLN   1168
# ..           ...                                          ...    ...
# 31          3660  furosemide (LASIX) 10 mg/mL injection 40 mg   1033
# 32          3660                                   Furosemide   1033
# 33          3660           furosemide (LASIX) injection 20 mg   1005
# 34          3660                     FUROSEMIDE 80 MG PO TABS    995
# 35          None                                   FUROSEMIDE    741
# 36          None      4 ML VIAL : FUROSEMIDE 10 MG/ML IJ SOLN    539
# 37          None                     FUROSEMIDE 40 MG PO TABS    532
# 38          None                                        LASIX    521
# 39          None                     FUROSEMIDE 20 MG PO TABS    273
# 40          None                               FUROSEMIDE INJ    261
# 41          None         2 ML  -  FUROSEMIDE 10 MG/ML IJ SOLN    260
# 42          None            FUROSEMIDE 10 MG/1 ML 2ML SDV INJ    229
# 43          None            FUROSEMIDE 10 MG/1 ML 4ML SDV INJ    218
# 44          None                                   Furosemide    208
# 45          None                                        Lasix     92
# 46          None                     FUROSEMIDE 80 MG PO TABS     84
# 47          None                         FUROSEMIDE 40 MG TAB     57
# 48          None                         FUROSEMIDE 20 MG TAB     40
# 49          None                 furosemide (LASIX) inj 40 mg     26
# 50          None                                   furosemide     14
# 51          None                 furosemide (LASIX) tab 40 mg      7
# 52          None                 furosemide (LASIX) inj 20 mg      5
# 53          None           furosemide (LASIX) injection 20 mg      4
# 54          None           furosemide (LASIX) injection 40 mg      3
# 55          2854                                   FUROSEMIDE      3
# 56          None                  FUROSEMIDE 10 MG/ML IJ SOLN      2
# 57          None                FUROSEMIDE 20 MG/2ML INJ SOLN      1
# 58          None              furosemide (LASIX) tablet 40 mg      1
# 59          None                 FUROSEMIDE 10 MG/ML INJ SOLN      1
# 60          None                       Furosemide 10mg/ml SSO      1
#
# [61 rows x 3 columns]

# %% [markdown]
# More hits, but not many more HICL codes:

# %%
med['drughiclseqno'].value_counts()
# Out:
# 3660    34
# 2854     1
# Name: drughiclseqno, dtype: int64

# %% [markdown]
# Some codes are used for multiple drugs, so let's double check that 2854 is OK to include.

# %%
# cohort with exclusions applied
hicl = 2854
query = f"""
select
    drughiclseqno, drugname, count(*) as n
from `physionet-data.eicu_crd.medication` med
where drughiclseqno = {hicl}
group by drugname, drughiclseqno
order by n desc
"""
med = run_query(query)
print(med.shape)
display(med)
# Out:
# (28, 3)
#     drughiclseqno                 drugname    n
# 0            2854                     None  216
# 1            2854          NovoLOG Flexpen   10
# 2            2854  oxyCODONE-acetaminophen    7
# 3            2854       methylPREDNISolone    5
# 4            2854            LABETALOL HCL    5
# 5            2854             azithromycin    4
# 6            2854              CLOPIDOGREL    4
# 7            2854      PANTOPRAZOLE SODIUM    3
# 8            2854               FUROSEMIDE    3
# 9            2854               predniSONE    3
# 10           2854               amLODIPine    2
# 11           2854                 traMADol    2
# 12           2854               folic acid    2
# 13           2854               GABAPENTIN    2
# 14           2854            metroNIDAZOLE    2
# 15           2854                LORazepam    1
# 16           2854              ALLOPURINOL    1
# 17           2854            levETIRAcetam    1
# 18           2854                 TRANDATE    1
# 19           2854                    Xanax    1
# 20           2854                NITROSTAT    1
# 21           2854               clonazePAM    1
# 22           2854                LACTULOSE    1
# 23           2854                 CATAPRES    1
# 24           2854                 Levaquin    1
# 25           2854           SPIRONOLACTONE    1
# 26           2854            HYDROmorphone    1
# 27           2854                   MERREM    1

# %% [markdown]
# From the above, it's clear we don't want to include 2854 as it corresponds to many different drugs.
#
# Consequently, our final search will look for:
#
# * drughiclseqno = 3660
# * lower(drugname) like '%lasix%'
# * lower(drugname) like '%furosemide%'
#
# ```
# WHERE drughiclseqno = 3660
#    OR lower(drugname) like '%lasix%'
#    OR lower(drugname) like '%furosemide%'
# ```

# %% [markdown]
# # Repeat the above for loop diuretics
#
# Repeat the above for other loop diuretics:
#
# * bumex
# * torsemide

# %%
def hicl_query(hicl):
    query = f"""
    select
        drughiclseqno, drugname, count(*) as n
    from `physionet-data.eicu_crd.medication` med
    where drughiclseqno = {hicl}
    group by drugname, drughiclseqno
    order by n desc
    """
    return run_query(query)

def drug_query(compound, *args):
    where_clause = f"WHERE lower(drugname) like '%{compound}%'"
    if args:
        for a in args:
            where_clause += f" OR lower(drugname) like '%{a}%'"
    query = f"""
    select
        drughiclseqno, drugname, count(*) as n
    from `physionet-data.eicu_crd.medication` med
    {where_clause}
    group by drugname, drughiclseqno
    order by n desc
    """
    return run_query(query)

# %%
med = drug_query('bumex', 'bumetanide')
print(med.shape)
display(med)
# Out:
# (9, 3)
#   drughiclseqno                            drugname     n
# 0          3664                               BUMEX  2962
# 1          3664                          BUMETANIDE  2012
# 2          3664  BUMETANIDE 0.25 MG/1ML 4ML SDV INJ  1289
# 3          3664                               Bumex  1186
# 4          None                               BUMEX   172
# 5          None  BUMETANIDE 0.25 MG/1ML 4ML SDV INJ    60
# 6          None                          BUMETANIDE     9
# 7         18084                               BUMEX     2
# 8         18084                          BUMETANIDE     1

# %%
med = hicl_query(3664)
display(med)
# Out:
#    drughiclseqno                            drugname     n
# 0           3664                                None  6924
# 1           3664                               BUMEX  2962
# 2           3664                          BUMETANIDE  2012
# 3           3664  BUMETANIDE 0.25 MG/1ML 4ML SDV INJ  1289
# 4           3664                               Bumex  1186

# %%
med = hicl_query(18084)
display(med)
# Out:
#     drughiclseqno                 drugname     n
# 0           18084                     None  4822
# 1           18084                  HumaLOG   837
# 2           18084                LORazepam   770
# 3           18084                   PEPCID   294
# 4           18084        heparin (porcine)   282
# 5           18084                 Protonix   185
# 6           18084                    ZOSYN   166
# 7           18084               ASPIRIN EC   127
# 8           18084               predniSONE   112
# 9           18084                 Coumadin    86
# 10          18084      meTOPROLOL tartrate    80
# 11          18084                 Levaquin    73
# 12          18084  SODIUM BICARBONATE 8.4%    62
# 13          18084                 nalOXone    61
# 14          18084                  ASPIRIN    47
# 15          18084               amiodarone    46
# 16          18084                   COZAAR    25
# 17          18084               ALPRAZolam    20
# 18          18084    fentaNYL citrate (PF)    17
# 19          18084                  LANOXIN    16
# 20          18084                   FLOMAX    16
# 21          18084            levETIRAcetam    11
# 22          18084                ceFAZolin    10
# 23          18084      HALOPERIDOL LACTATE     8
# 24          18084                 morphine     4
# 25          18084                  LOVENOX     3
# 26          18084      NORMAL SALINE FLUSH     2
# 27          18084            levothyroxine     2
# 28          18084                    BUMEX     2
# 29          18084                   LANTUS     1
# 30          18084                    ZOCOR     1
# 31          18084               BUMETANIDE     1
# 32          18084                 DIAZEPAM     1
# 33          18084    IPRATROPIUM-ALBUTEROL     1
# 34          18084              EPINEPHrine     1
# 35          18084              CLOPIDOGREL     1
# 36          18084       METOCLOPRAMIDE HCL     1
# 37          18084               folic acid     1

# %% [markdown]
# So for bumex: `WHERE drughiclseqno = 3664 OR lower(drugname) like '%bumex%' OR lower(drugname) like '%bumetanide%'`

# %% [markdown]
# ### torsemide

# %%
med = drug_query('torsemide')
print(med.shape)
display(med)
# Out:
# (0, 3)
# Empty DataFrame
# Columns: [drughiclseqno, drugname, n]
# Index: []

# %%
med = drug_query('tors')
print(med.shape)
display(med)
# Out:
# (0, 3)
# Empty DataFrame
# Columns: [drughiclseqno, drugname, n]
# Index: []

# %% [markdown]
# # Repeat for NSAIDs
#
# Also repeat the above for NSAIDs:
#
# * ?Acetaminophen
# * Aspirin
# * Diflunisal
# * Choline magnesium trisalicylate
# * Salsalate
# * Naproxen
# * Ibuprofen
# * Ketoprofen
# * Flurbiprofen
# * Oxaprozin
# * Diclofenac
# * Etodolac
# * Indomethacin
# * Tolmetin
# * Sulindac
# * Meloxicam
# * Piroxicam
# * Meclofenamate
# * Mefenamic acid
# * Nabumetone
# * toradol/ketorolac
#
# ? Selective COX-2 inhibitors
#
# * Celecoxib
#
# Spoiler alert: we only found aspirin/ibuprofen/toradol in the data:
#
# `WHERE drughiclseqno = 1820 OR lower(drugname) like '%aspirin%' OR lower(drugname) like '%ecotrin%'`
# `WHERE drughiclseqno = 3723 OR lower(drugname) like '%ibuprofen%' OR lower(drugname) like '%motrin%'`
# `WHERE drughiclseqno = 5175 OR lower(drugname) like '%toradol%' OR lower(drugname) like '%ketorolac%'`

# %% [markdown]
# ## Toradol/Ketorolac

# %%
med = drug_query('toradol')
print(med.shape)
display(med)
# Out:
# (2, 3)
#   drughiclseqno drugname     n
# 0          5175  TORADOL  1875
# 1          None  TORADOL    95

# %%
med = hicl_query(5175)
print(med.shape)
display(med)
# Out:
# (6, 3)
#    drughiclseqno                        drugname     n
# 0           5175                            None  7486
# 1           5175                         TORADOL  1875
# 2           5175                   KETOROLAC INJ  1705
# 3           5175          KETOROLAC TROMETHAMINE  1530
# 4           5175  KETOROLAC 30 MG/ML 1ML SDV INJ  1227
# 5           5175                       KETOROLAC  1224

# %%
med = drug_query('toradol', 'ketorolac')
print(med.shape)
display(med)
# Out:
# (11, 3)
#    drughiclseqno                        drugname     n
# 0           5175                         TORADOL  1875
# 1           5175                   KETOROLAC INJ  1705
# 2           5175          KETOROLAC TROMETHAMINE  1530
# 3           5175  KETOROLAC 30 MG/ML 1ML SDV INJ  1227
# 4           5175                       KETOROLAC  1224
# 5           None                   KETOROLAC INJ   216
# 6           None                         TORADOL    95
# 7           None                       KETOROLAC    84
# 8           None  KETOROLAC 30 MG/ML 1ML SDV INJ    46
# 9           None          KETOROLAC TROMETHAMINE     6
# 10         21996          KETOROLAC TROMETHAMINE     2

# %% [markdown]
# ## Aspirin

# %%
med = drug_query('aspirin')
print(med.shape)
display(med)

med = hicl_query(1820)
print(med.shape)
display(med)

med = drug_query('ecotrin')
print(med.shape)
display(med)

med = hicl_query(1794)
display(med)

med = hicl_query(21996)
display(med)
# Out:
# (45, 3)
#    drughiclseqno                       drugname     n
# 0           1820          ASPIRIN 81 MG PO CHEW  9509
# 1           1820                        ASPIRIN  9167
# 2           1820                        aspirin  8447
# 3           1820         ASPIRIN 325 MG PO TABS  5075
# 4           1820       ASPIRIN EC 81 MG PO TBEC  4717
# 5           1820   ASPIRIN (BABY ASA) 81 MG TAB  4151
# 6           1820                     ASPIRIN EC  2950
# 7           1820            ASPIRIN, CHILDREN'S  2881
# 8           1820           ASPIRIN 81 MG EC TAB  2508
# 9           1820              ASPIRIN 325MG TAB  1920
# 10          1820  ASPIRIN   81 MG ORAL CHEW TAB  1835
# 11          1820         aspirin chew tab 81 mg  1826
# 12          1820          ASPIRIN 325 MG TABLET  1779
# 13          1820       ASPIRIN 300 MG RECT SUPP  1609
# 14          1820          ASPIRIN 325 MG EC TAB  1481
# 15          1820             ASPIRIN (CHEWABLE)  1475
# 16          None          ASPIRIN 81 MG PO CHEW  1340
# 17          1820  ASPIRIN 81 MG CHEWABLE TABLET  1336
# 18          1820               ASPIRIN CHEWABLE  1283
# 19          1820      ASPIRIN EC 325 MG PO TBEC  1264
# 20          None         ASPIRIN 300 MG RE SUPP  1239
# 21          1820          aspirin 81 mg po chew  1239
# 22          None         ASPIRIN 325 MG PO TABS   608
# 23          1820         ASPIRIN 300 MG RE SUPP   594
# 24          None                        ASPIRIN   377
# 25          None       ASPIRIN EC 81 MG PO TBEC   308
# 26          None   ASPIRIN (BABY ASA) 81 MG TAB   140
# 27         18084                     ASPIRIN EC   127
# 28          None               ASPIRIN CHEWABLE   113
# 29          None          ASPIRIN 325 MG TABLET   108
# 30          None            ASPIRIN, CHILDREN'S   103
# 31          None           ASPIRIN 81 MG EC TAB    96
# 32          None  ASPIRIN   81 MG ORAL CHEW TAB    81
# 33          None              ASPIRIN 325MG TAB    72
# 34          None       ASPIRIN 300 MG RECT SUPP    59
# 35          None          ASPIRIN 325 MG EC TAB    52
# 36         18084                        ASPIRIN    47
# 37          None      ASPIRIN EC 325 MG PO TBEC    37
# 38          None                        aspirin    31
# 39          None                     ASPIRIN EC    25
# 40          None          aspirin 81 mg po chew    23
# 41          None         aspirin chew tab 81 mg     8
# 42          None             ASPIRIN (CHEWABLE)     2
# 43         21996                        ASPIRIN     1
# 44          1794                        ASPIRIN     1
# (25, 3)
#     drughiclseqno                       drugname      n
# 0            1820                           None  18608
# 1            1820          ASPIRIN 81 MG PO CHEW   9509
# 2            1820                        ASPIRIN   9167
# 3            1820                        aspirin   8447
# 4            1820         ASPIRIN 325 MG PO TABS   5075
# 5            1820       ASPIRIN EC 81 MG PO TBEC   4717
# 6            1820   ASPIRIN (BABY ASA) 81 MG TAB   4151
# 7            1820                     ECOTRIN EC   3967
# 8            1820                     ASPIRIN EC   2950
# 9            1820            ASPIRIN, CHILDREN'S   2881
# 10           1820                 BAYER CHEWABLE   2800
# 11           1820           ASPIRIN 81 MG EC TAB   2508
# 12           1820              ASPIRIN 325MG TAB   1920
# 13           1820  ASPIRIN   81 MG ORAL CHEW TAB   1835
# 14           1820         aspirin chew tab 81 mg   1826
# 15           1820          ASPIRIN 325 MG TABLET   1779
# 16           1820       ASPIRIN 300 MG RECT SUPP   1609
# 17           1820          ASPIRIN 325 MG EC TAB   1481
# 18           1820             ASPIRIN (CHEWABLE)   1475
# 19           1820  ASPIRIN 81 MG CHEWABLE TABLET   1336
# 20           1820               ASPIRIN CHEWABLE   1283
# 21           1820      ASPIRIN EC 325 MG PO TBEC   1264
# 22           1820          aspirin 81 mg po chew   1239
# 23           1820                        ECOTRIN    959
# 24           1820         ASPIRIN 300 MG RE SUPP    594
# (4, 3)
#   drughiclseqno    drugname     n
# 0          1820  ECOTRIN EC  3967
# 1          1820     ECOTRIN   959
# 2          None     ECOTRIN    97
# 3          None  ECOTRIN EC     8
#    drughiclseqno drugname  n
# 0           1794  ASPIRIN  1
# 1           1794     None  1

# %% [markdown]
# ## Diflunisal

# %%
med = drug_query('diflun')
print(med.shape)
display(med)

# %% [markdown]
# ## Choline magnesium trisalicylate

# %%
med = drug_query('choline')
print(med.shape)
display(med)

# %%
med = drug_query('trilisate')
print(med.shape)
display(med)

# %% [markdown]
# ## Salsalate

# %%
med = drug_query('salsalate')
print(med.shape)
display(med)

# %% [markdown]
# ## Naproxen

# %%
med = drug_query('naproxen')
print(med.shape)
display(med)

# %% [markdown]
# ## Ibuprofen

# %%
med = drug_query('ibuprofen')
print(med.shape)
display(med)

# %%
med = hicl_query(3723)
print(med.shape)
display(med)

# %%
med = drug_query('motrin')
print(med.shape)
display(med)

# %% [markdown]
# ## Ketoprofen

# %%
med = drug_query('ketoprofen')
print(med.shape)
display(med)

# %% [markdown]
# ## Flurbiprofen

# %%
med = drug_query('flurbiprofen')
print(med.shape)
display(med)

# %% [markdown]
# ## Oxaprozin

# %%
med = drug_query('oxaprozin')
print(med.shape)
display(med)

# %% [markdown]
# ## Diclofenac

# %%
med = drug_query('diclofenac')
print(med.shape)
display(med)

# %% [markdown]
# ## Etodolac

# %%
med = drug_query('etodolac')
print(med.shape)
display(med)

# %% [markdown]
# ## Indomethacin

# %%
med = drug_query('indomethacin')
print(med.shape)
display(med)

# %% [markdown]
# ## Tolmetin

# %%
med = drug_query('tolmetin')
print(med.shape)
display(med)

# %% [markdown]
# ## Sulindac

# %%
med = drug_query('sulindac')
print(med.shape)
display(med)

# %% [markdown]
# ## Meloxicam

# %%
med = drug_query('meloxicam')
print(med.shape)
display(med)

# %% [markdown]
# ## Piroxicam

# %%
med = drug_query('piroxicam')
print(med.shape)
display(med)

# %% [markdown]
# ## Meclofenamate

# %%
med = drug_query('meclofenamate')
print(med.shape)
display(med)

# %% [markdown]
# ## Mefenamic acid

# %%
med = drug_query('mefenamic')
print(med.shape)
display(med)

# %% [markdown]
# ## Nabumetone

# %%
med = drug_query('nabumetone')
print(med.shape)
display(med)

# %%
med = drug_query('relafen')
print(med.shape)
display(med)

# %% [markdown]
# ## Celecoxib (COX-2 inhibitor)

# %%
med = drug_query('celecoxib')
print(med.shape)
display(med)

# %%
med = drug_query('celebrex')
print(med.shape)
display(med)
